# %%
import matplotlib.pyplot as plt
import kex_data
import kex_headers
import numpy as np
import importlib

import visual

# %%
dicom_recon = kex_data.get_recon()

# %%
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(20,20))
rows = dict(zip(dicom_recon.keys(), axes))
importlib.reload(visual)
for dkey, img in dicom_recon.items():
    row = rows[dkey]
    position = [47, 120,100]
    views = visual.multiple_views(img, position, row)
    visual.same_colorbar(fig, views, row)
    dimlabels = kex_headers.IMAGE_DIMENSION_TITLES
    visual.label_multiple_views(dimlabels, position, row)
    visual.title_position_multiple_views(dkey, position, row, dimlabels)
