# %%
import matplotlib.pyplot as plt
import matplotlib
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 22}

matplotlib.rc('font', **font)

# %%
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
# add a subplot with no frame
ax2=plt.subplot(222, frameon=False)

# %%
# add a polar subplot
plt.subplot(223, projection='polar')

# %%
# add a red subplot that shares the x-axis with ax1
plt.subplot(224, sharex=ax1, facecolor='red')

# %%
# add ax2 to the figure again
plt.subplot(ax2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-cd0ff940b538> in <module>
#       1 # add ax2 to the figure again
# ----> 2 plt.subplot(ax2)
#
# ~\AppData\Local\Continuum\anaconda3\envs\HugoMexEnvironment\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1074
#    1075     fig = gcf()
# -> 1076     a = fig.add_subplot(*args, **kwargs)
#    1077     bbox = a.bbox
#    1078     byebye = []
#
# ~\AppData\Local\Continuum\anaconda3\envs\HugoMexEnvironment\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1387             a = args[0]
#    1388             if a.get_figure() is not self:
# -> 1389                 raise ValueError(
#    1390                     "The Subplot must have been created in the present figure")
#    1391             # make a key for the subplot (which includes the axes object id
#
# ValueError: The Subplot must have been created in the present figure
